# %% [markdown]
# Adapted slightly by me, Wayne, from https://github.com/TDUPB/jupyter_notebook/blob/master/08_2Schwingungen_multipliziert.ipynb to show it runs in JupyterLab now when you also add jupyter_bokeh, see https://github.com/bokeh/jupyter_bokeh, so it is included in build. (It didn't seem to work as well if tried adding into MyBinder after, although installing `jupyter_bokeh` via pip did allow it to work if you first switched to classic, ran it, and then switched back to JupyterLab. Obviously this is better. **Works in classic notebook interface, as well as JupyterLab.** In Voila, it shows plot area but doesn't draw the lines on it or retain interactivtiy.

# %% [markdown]
# ### Bei erstmaligen Öffnen der Datei: Bitte drücken Sie oberhalb in der Toolbar folgenden Button:
#
# <img style="float: left;" src="https://tdupb.github.io/restart_button.PNG" />
#
# ### Bestätigen Sie "Restart and Run All Cells"

# %%
from IPython.display import HTML, display, IFrame

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Klicken um Programm-Code (input cells) zu zeigen/verbergen"></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Klicken um Programm-Code (input cells) zu zeigen/verbergen"></form>

# %%
from ipywidgets import interact, interactive, fixed, interact_manual # An dieser Stelle und den folgenden "Import" -Aufrufen werden aus Programmbibliotheken fertiger Programmcode und dessen "Funktionen" eingebunden.
import numpy as np
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
from bokeh.models import Span
from ipywidgets import interact, interactive, fixed, interact_manual
output_notebook()
#https://docs.bokeh.org/en/latest/docs/user_guide/notebook.html
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(-5, 5, 3000)
y0 = np.sin(x)

tools = 'pan', 'crosshair', 'wheel_zoom', 'box_zoom', 'reset', 'save'  #https://docs.bokeh.org/en/latest/docs/user_guide/tools.html#userguide-tools-pandrag

TOOLTIPS = [ ("(x,y)", "($x, $y)")] # Hover Tools ermöglicht das Ablesen von x,y- Werten der Datenpunkte


p1 = figure(title="2 Sensor-Signale: Harmonische Schwingung", height=600, width=900,background_fill_color="#696969", y_range=(-10,10), 
           tooltips=TOOLTIPS, tools=tools, toolbar_location="below")#('pan', 'crosshair')) # Aufrufen der Funktionen: u.a. Die "Tools"

p1.xaxis.axis_label = 'Zeit in sec.'
p1.yaxis.axis_label = 'Spannung in Volt'

r1 = p1.line(x, y0, color="#FF0000", line_width=2) # Tabelle mit Hex-Code Farben https://www.w3schools.com/colors/colors_names.asp
r2 = p1.line(x, y0, color="#0000CD", line_width=2)
r3 = p1.line(x, y0, color="#FFF8DC", line_width=2)

p1.ygrid.minor_grid_line_color = 'navy'
p1.ygrid.minor_grid_line_alpha = 0.1

p1.xgrid.minor_grid_line_color = 'navy'
p1.xgrid.minor_grid_line_alpha = 0.1

vline = Span(location=0, dimension='height', line_color='green', line_width=1)
hline = Span(location=0, dimension='width', line_color='green', line_width=1)
p1.renderers.extend([vline, hline])

def push1(Funkt_ROT="sin", Frequenz1=1, Amplitude1=1, Phasenverschiebung1=0, Offset1=0):
    if   Funkt_ROT == "sin": func1 = np.sin
    elif Funkt_ROT == "cos": func1 = np.cos
    r1.data_source.data['y'] = Amplitude1 * func1(2*np.pi*Frequenz1 * x + (Phasenverschiebung1/360)*2*np.pi) + Offset1
    
    r3.data_source.data['y'] = r1.data_source.data['y']* r2.data_source.data['y']
   
    push_notebook()

def push2(Funkt_BLAU="sin", Frequenz2=1, Amplitude2=1, Phasenverschiebung2=22.5, Offset2=-6.85):
    
    if   Funkt_BLAU == "sin": func2 = np.sin
    elif Funkt_BLAU == "cos": func2 = np.cos
    r2.data_source.data['y'] = Amplitude2 * func2(2*np.pi*Frequenz2*x + (Phasenverschiebung2/360)*2*np.pi) + Offset2
 
    
    r3.data_source.data['y'] = r1.data_source.data['y']* r2.data_source.data['y']
    
    push_notebook()


    
show(p1, notebook_handle=True)



widget1 = interact(push1, Funkt_ROT=["sin", "cos"], Frequenz1=(1,50), Amplitude1=(0.5, 20, 0.1), Phasenverschiebung1=(0, 360, 0.01), Offset1=(-10, 10, 0.05))

widget2 = interact(push2, Funkt_BLAU=["sin", "cos"], Frequenz2=(1,50), Amplitude2=(0.5, 20, 0.1), Phasenverschiebung2=(0, 360, 0.01), Offset2=(-10, 10, 0.05))
# Out:
#   <div class="bk-root" id="c81f4c8d-ba6c-4d74-80f9-c45f2e3eee73" data-root-id="1404"></div>
# interactive(children=(Dropdown(description='Funkt_ROT', options=('sin', 'cos'), value='sin'), IntSlider(value=…
# interactive(children=(Dropdown(description='Funkt_BLAU', options=('sin', 'cos'), value='sin'), IntSlider(value…
